# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import analytics

# %%
ph_data = analytics.get_data()["PHL"]
gdp = ph_data[ph_data['indicator_code'] == 'NY.GDP.MKTP.KD']
gdp.plot(kind='line', x='year', y='value', title='GDP in 2005 USD', legend=False)
